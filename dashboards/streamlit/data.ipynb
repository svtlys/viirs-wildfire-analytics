# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
baseline = pd.read_csv('../../data/enhanced_baseline_model_results.csv')
baseline.head()
# Out:
#    lr_frp  lr_predict_frp  lr_frp_difference     lr_R2    lr_RMSE    lr_MAE  \
# 0    4.09       13.473736          -9.383736  0.151459  19.154463  7.959108
# 1   24.22       18.788881           5.431119  0.151459  19.154463  7.959108
# 2   11.06       11.026460           0.033540  0.151459  19.154463  7.959108
# 3    7.04       19.721451         -12.681451  0.151459  19.154463  7.959108
# 4    4.38        2.345195           2.034805  0.151459  19.154463  7.959108
#
#    xgb_frp  xgb_predict_frp  xgb_frp_difference    xgb_R2   xgb_RMSE  \
# 0     4.09         7.620114           -3.530114  0.411874  15.946634
# 1    24.22        19.259491            4.960509  0.411874  15.946634
# 2    11.06        11.808919           -0.748919  0.411874  15.946634
# 3     7.04         5.201190            1.838810  0.411874  15.946634
# 4     4.38         5.752706           -1.372706  0.411874  15.946634
#
#     xgb_MAE  gb_frp  gb_predict_frp  gb_frp_difference     gb_R2    gb_RMSE  \
# ...

# %%
model_results = pd.read_csv('../../data/model_results.csv')
model_results.head()
# Out:
#   model_name  is_grid_search  used_pca  pca_components  \
# 0         lr           False     False             NaN
# 1      lr_gs            True      True            10.0
# 2        xgb           False     False             NaN
# 3     xgb_gs            True      True            10.0
# 4         gb           False     False             NaN
#
#                                           parameters  rmse_original  \
# 0  {"memory": "None", "model": "LinearRegression(...      19.366145
# 1  {"pca__n_components": "10", "ridge__alpha": "1...      19.492246
# 2  {"base_score": "None", "booster": "None", "cal...      16.504836
# 3  {"pca__n_components": "10", "xgb__learning_rat...      16.791109
# 4  {"alpha": "0.9", "ccp_alpha": "0.0", "criterio...      16.832046
#
#    mae_original  r2_original  rmse_log   mae_log    r2_log
# 0      5.608732     0.132601  0.596161  0.415207  0.524785
# 1      5.771453     0.121268  0.612160  0.438251  0.498937
# ...

# %%
model_predictions = pd.read_csv('../../data/model_predictions.csv')
model_predictions.head()
# Out:
#    enhanced_lr_frp  enhanced_lr_predict_frp  enhanced_lr_frp_difference  \
# 0             4.09                 7.756601                   -3.666601
# 1            24.22                12.463449                   11.756551
# 2            11.06                 9.260346                    1.799654
# 3             7.04                 9.612519                   -2.572519
# 4             4.38                 5.062916                   -0.682916
#
#    enhanced_lr_R2  enhanced_lr_RMSE  enhanced_lr_MSE  enhanced_lr_MAE  \
# 0        0.132601         19.366145       375.047563         5.608732
# 1        0.132601         19.366145       375.047563         5.608732
# 2        0.132601         19.366145       375.047563         5.608732
# 3        0.132601         19.366145       375.047563         5.608732
# 4        0.132601         19.366145       375.047563         5.608732
#
#    enhanced_lr_gs_frp  enhanced_lr_gs_predict_frp  \
# 0                4.09                    8.254870
# ...

# %%
model_predictions.columns
# Out:
# Index(['enhanced_lr_frp', 'enhanced_lr_predict_frp',
#        'enhanced_lr_frp_difference', 'enhanced_lr_R2', 'enhanced_lr_RMSE',
#        'enhanced_lr_MSE', 'enhanced_lr_MAE', 'enhanced_lr_gs_frp',
#        'enhanced_lr_gs_predict_frp', 'enhanced_lr_gs_frp_difference',
#        'enhanced_lr_gs_R2', 'enhanced_lr_gs_RMSE', 'enhanced_lr_gs_MSE',
#        'enhanced_lr_gs_MAE', 'enhanced_xgb_frp', 'enhanced_xgb_predict_frp',
#        'enhanced_xgb_frp_difference', 'enhanced_xgb_R2', 'enhanced_xgb_RMSE',
#        'enhanced_xgb_MSE', 'enhanced_xgb_MAE', 'enhanced_xgb_gs_frp',
#        'enhanced_xgb_gs_predict_frp', 'enhanced_xgb_gs_frp_difference',
#        'enhanced_xgb_gs_R2', 'enhanced_xgb_gs_RMSE', 'enhanced_xgb_gs_MSE',
#        'enhanced_xgb_gs_MAE', 'enhanced_gb_frp', 'enhanced_gb_predict_frp',
#        'enhanced_gb_frp_difference', 'enhanced_gb_R2', 'enhanced_gb_RMSE',
#        'enhanced_gb_MSE', 'enhanced_gb_MAE'],
#       dtype='object')

# %%
model_detailed_predictions = pd.read_csv('../../data/model_predictions_detailed.csv')
model_detailed_predictions.head()
# Out:
#    enhanced_lr_frp  enhanced_lr_predict_frp  enhanced_lr_frp_difference  \
# 0             4.09                 7.756601                   -3.666601
# 1            24.22                12.463449                   11.756551
# 2            11.06                 9.260346                    1.799654
# 3             7.04                 9.612519                   -2.572519
# 4             4.38                 5.062916                   -0.682916
#
#    enhanced_lr_R2  enhanced_lr_RMSE  enhanced_lr_MSE  enhanced_lr_MAE  \
# 0        0.132601         19.366145       375.047563         5.608732
# 1        0.132601         19.366145       375.047563         5.608732
# 2        0.132601         19.366145       375.047563         5.608732
# 3        0.132601         19.366145       375.047563         5.608732
# 4        0.132601         19.366145       375.047563         5.608732
#
#    enhanced_lr_abs_error  enhanced_lr_percent_error  enhanced_lr_log_frp  ...  \
# ...

# %%
model_detailed_predictions.columns
# Out:
# Index(['enhanced_lr_frp', 'enhanced_lr_predict_frp',
#        'enhanced_lr_frp_difference', 'enhanced_lr_R2', 'enhanced_lr_RMSE',
#        'enhanced_lr_MSE', 'enhanced_lr_MAE', 'enhanced_lr_abs_error',
#        'enhanced_lr_percent_error', 'enhanced_lr_log_frp',
#        'enhanced_lr_log_predict_frp', 'enhanced_lr_gs_frp',
#        'enhanced_lr_gs_predict_frp', 'enhanced_lr_gs_frp_difference',
#        'enhanced_lr_gs_R2', 'enhanced_lr_gs_RMSE', 'enhanced_lr_gs_MSE',
#        'enhanced_lr_gs_MAE', 'enhanced_lr_gs_abs_error',
#        'enhanced_lr_gs_percent_error', 'enhanced_lr_gs_log_frp',
#        'enhanced_lr_gs_log_predict_frp', 'enhanced_xgb_frp',
#        'enhanced_xgb_predict_frp', 'enhanced_xgb_frp_difference',
#        'enhanced_xgb_R2', 'enhanced_xgb_RMSE', 'enhanced_xgb_MSE',
#        'enhanced_xgb_MAE', 'enhanced_xgb_abs_error',
#        'enhanced_xgb_percent_error', 'enhanced_xgb_log_frp',
#        'enhanced_xgb_log_predict_frp', 'enhanced_xgb_gs_frp',
# ...
