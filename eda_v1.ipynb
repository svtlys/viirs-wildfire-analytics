# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "data/fire_nrt_J1V-C2_725729.csv"
df = pd.read_csv(file_path)

# %% [markdown]
# ## Univariate Analysis
# ### Plotting a hisogram, kdeplot, and boxplot of all columns

# %% [markdown]
# ### Brightness
# #### Thermal brightness (Kelvin)

# %%
sns.histplot(df["brightness"], bins=50, kde=True)
plt.show()

# %%
sns.kdeplot(df['brightness'], fill=True, color='orange')
plt.xlim(left=0)
plt.show()

# %%
plt.boxplot(df["brightness"], vert = True, patch_artist=True, boxprops=dict(facecolor='lightgreen', color='black'))
plt.show()

# %% [markdown]
# ###  Scan
# #### Pixel width
# Is this a right skew?

# %%
sns.histplot(df["scan"], bins=50, kde=True)
plt.show()

# %%
sns.kdeplot(df['scan'], fill=True, color='orange')
plt.xlim(left=0)
plt.show()

# %%
plt.boxplot(df["scan"], vert = True, patch_artist=True, boxprops=dict(facecolor='lightgreen', color='black'))
plt.show()

# %% [markdown]
# ## Track
# ### Pixel Height

# %%
sns.histplot(df["track"], bins=50, kde=True)
plt.show()

# %%
sns.kdeplot(df['track'], fill=True, color='orange')
plt.xlim(left=0)
plt.show()

# %%
plt.boxplot(df["track"], vert = True, patch_artist=True, boxprops=dict(facecolor='lightgreen', color='black'))
plt.show()

# %% [markdown]
# ## Bright_t31: Brightness Temperature

# %%
sns.histplot(df["bright_t31"], bins=50, kde=True)
plt.show()

# %%
sns.kdeplot(df['bright_t31'], fill=True, color='orange')
plt.xlim(left=0)
plt.show()

# %%
plt.boxplot(df["bright_t31"], vert = True, patch_artist=True, boxprops=dict(facecolor='lightgreen', color='black'))
plt.show()

# %% [markdown]
# ## frp: Fire Radiative Power (megawatts)
# ### Will likely need some data cleaning?

# %%
fig, ax = plt.subplots(figsize=(8, 5))

sns.histplot(df["frp"], bins=50, kde=True)

# adjusted x axis to see what's happening 
ax.set_xlim(0,100)
plt.show()

# %%
sns.kdeplot(df['frp'], fill=True, color='orange')
plt.xlim(left=0)
plt.show()

# %%
plt.boxplot(df["frp"], vert = True, patch_artist=True, boxprops=dict(facecolor='lightgreen', color='black'))
plt.show()
